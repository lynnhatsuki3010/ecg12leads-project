# %% [markdown]
# # **IMPORT LIBRARY**

# %%
# 📘 01_preprocessing.ipynb
# Tác vụ:
# - Tạo metadata từ WFDB records
# - Mapping SNOMED & resolve Unknown qua API
# - Lọc nhiễu tín hiệu ECG
# - Chuẩn hóa & lưu .npy
# - Chia train/val/test

import os, sys
sys.path.append("../")

from processing.preprocess import run_preprocessing
from processing.feature_extraction import process_and_save_ecg_files
from processing.split_dataset import run_split_dataset
from processing.denoised_ecg import load_ecg_mat, denoise_all_leads

# %% [markdown]
# # **TIỀN XỬ LÍ METADATA**

# %%
# === Bước 1: Tiền xử lý metadata WFDB ===
# Tạo patient_metadata_clean.xlsx

run_preprocessing()

# Sau bước này:
# -> data/processed/patient_metadata_clean.xlsx
# -> data/processed/Unknown_SNOMED_Codes_Resolved_NEW.xlsx
# Out:
# ✅ Tạo metadata xong: 45152 bản ghi
# 🧩 Mapping SNOMED lần đầu (có thể còn Unknown)
# ✅ Đã resolve SNOMED Unknown -> E:\NCKH - 2026\ECG Project\data\processed\Unknown_SNOMED_Codes_Resolved_NEW.xlsx
# 🔍 Tải 55 mã SNOMED đã resolved
# 💾 Đã lưu metadata sạch: E:\NCKH - 2026\ECG Project\data\processed\patient_metadata_clean.xlsx

# %% [markdown]
# # **LỌC NHIỄU VÀ CHUẨN HÓA ECG**

# %%
import pandas as pd

# === Bước 2: Lọc nhiễu và lưu file .npy ===

# 1️⃣ Đọc danh sách file từ metadata
metadata_path = r"E:\NCKH - 2026\ECG Project\data\processed\patient_metadata_clean.xlsx"
df = pd.read_excel(metadata_path)
file_paths = df["file_path"].tolist()

# 2️⃣ Chạy xử lý tín hiệu
processed_dir = r"E:\NCKH - 2026\ECG Project\data\processed\ecg_lead6_npy"
valid_indices = process_and_save_ecg_files(
    X_paths=file_paths,
    save_dir=processed_dir,
    fs=500,
    verbose=True
)

print(f"✅ Hoàn tất xử lý tín hiệu cho {len(valid_indices)} bản ghi hợp lệ")
# Out:
# ✓ Đã xử lý 100/44848 file
# ✓ Đã xử lý 200/44848 file
# ✓ Đã xử lý 300/44848 file
# ✓ Đã xử lý 400/44848 file
# ✓ Đã xử lý 500/44848 file
# ✓ Đã xử lý 600/44848 file
# ✓ Đã xử lý 700/44848 file
# ✓ Đã xử lý 800/44848 file
# ✓ Đã xử lý 900/44848 file
# ✓ Đã xử lý 1000/44848 file
# ✓ Đã xử lý 1100/44848 file
# ✓ Đã xử lý 1200/44848 file
# ✓ Đã xử lý 1300/44848 file
# ✓ Đã xử lý 1400/44848 file
# ✓ Đã xử lý 1500/44848 file
# ✓ Đã xử lý 1600/44848 file
# ✓ Đã xử lý 1700/44848 file
# ✓ Đã xử lý 1800/44848 file
# ✓ Đã xử lý 1900/44848 file
# ✓ Đã xử lý 2000/44848 file
# ✓ Đã xử lý 2100/44848 file
# ✓ Đã xử lý 2200/44848 file
# ✓ Đã xử lý 2300/44848 file
# ✓ Đã xử lý 2400/44848 file
# ✓ Đã xử lý 2500/44848 file
# ✓ Đã xử lý 2600/44848 file
# ✓ Đã xử lý 2700/44848 file
# ✓ Đã xử lý 2800/44848 file
# ✓ Đã xử lý 2900/44848 file
# ✓ Đã xử lý 3000/44848 file
# ✓ Đã xử lý 3100/44848 file
# ✓ Đã xử lý 3200/44848 file
# ✓ Đã xử lý 3300/44848 file
# ✓ Đã xử lý 3400/44848 file
# ✓ Đã xử lý 3500/44848 file
# ✓ Đã xử lý 3600/44848 file
# ✓ Đã xử lý 3700/44848 file
# ✓ Đã xử lý 3800/44848 file
# ✓ Đã xử lý 3900/44848 file
# ✓ Đã xử lý 4000/44848 file
# ✓ Đã xử lý 4100/44848 file
# ✓ Đã xử lý 4200/44848 file
# ✓ Đã xử lý 4300/44848 file
# ✓ Đã xử lý 4400/44848 file
# ✓ Đã xử lý 4500/44848 file
# ✓ Đã xử lý 4600/44848 file
# ✓ Đã xử lý 4700/44848 file
# ✓ Đã xử lý 4800/44848 file
# ✓ Đã xử lý 4900/44848 file
# ✓ Đã xử lý 5000/44848 file
# ✓ Đã xử lý 5100/44848 file
# ✓ Đã xử lý 5200/44848 file
# ✓ Đã xử lý 5300/44848 file
# ✓ Đã xử lý 5400/44848 file
# ✓ Đã xử lý 5500/44848 file
# ✓ Đã xử lý 5600/44848 file
# ✓ Đã xử lý 5700/44848 file
# ✓ Đã xử lý 5800/44848 file
# ✓ Đã xử lý 5900/44848 file
# ✓ Đã xử lý 6000/44848 file
# ✓ Đã xử lý 6100/44848 file
# ✓ Đã xử lý 6200/44848 file
# ✓ Đã xử lý 6300/44848 file
# ✓ Đã xử lý 6400/44848 file
# ✓ Đã xử lý 6500/44848 file
# ✓ Đã xử lý 6600/44848 file
# ✓ Đã xử lý 6700/44848 file
# ✓ Đã xử lý 6800/44848 file
# ✓ Đã xử lý 6900/44848 file
# ✓ Đã xử lý 7000/44848 file
# ✓ Đã xử lý 7100/44848 file
# ✓ Đã xử lý 7200/44848 file
# ✓ Đã xử lý 7300/44848 file
# ✓ Đã xử lý 7400/44848 file
# ✓ Đã xử lý 7500/44848 file
# ✓ Đã xử lý 7600/44848 file
# ✓ Đã xử lý 7700/44848 file
# ✓ Đã xử lý 7800/44848 file
# ✓ Đã xử lý 7900/44848 file
# ✓ Đã xử lý 8000/44848 file
# ✓ Đã xử lý 8100/44848 file
# ✓ Đã xử lý 8200/44848 file
# ✓ Đã xử lý 8300/44848 file
# ✓ Đã xử lý 8400/44848 file
# ✓ Đã xử lý 8500/44848 file
# ✓ Đã xử lý 8600/44848 file
# ✓ Đã xử lý 8700/44848 file
# ✓ Đã xử lý 8800/44848 file
# ✓ Đã xử lý 8900/44848 file
# ✓ Đã xử lý 9000/44848 file
# ✓ Đã xử lý 9100/44848 file
# ✓ Đã xử lý 9200/44848 file
# ✓ Đã xử lý 9300/44848 file
# ✓ Đã xử lý 9400/44848 file
# ✓ Đã xử lý 9500/44848 file
# ✓ Đã xử lý 9600/44848 file
# ✓ Đã xử lý 9700/44848 file
# ✓ Đã xử lý 9800/44848 file
# ✓ Đã xử lý 9900/44848 file
# ✓ Đã xử lý 10000/44848 file
# ✓ Đã xử lý 10100/44848 file
# ✓ Đã xử lý 10200/44848 file
# ✓ Đã xử lý 10300/44848 file
# ✓ Đã xử lý 10400/44848 file
# ✓ Đã xử lý 10500/44848 file
# ✓ Đã xử lý 10600/44848 file
# ✓ Đã xử lý 10700/44848 file
# ✓ Đã xử lý 10800/44848 file
# ✓ Đã xử lý 10900/44848 file
# ✓ Đã xử lý 11000/44848 file
# ✓ Đã xử lý 11100/44848 file
# ✓ Đã xử lý 11200/44848 file
# ✓ Đã xử lý 11300/44848 file
# ✓ Đã xử lý 11400/44848 file
# ✓ Đã xử lý 11500/44848 file
# ✓ Đã xử lý 11600/44848 file
# ✓ Đã xử lý 11700/44848 file
# ✓ Đã xử lý 11800/44848 file
# ✓ Đã xử lý 11900/44848 file
# ✓ Đã xử lý 12000/44848 file
# ✓ Đã xử lý 12100/44848 file
# ✓ Đã xử lý 12200/44848 file
# ✓ Đã xử lý 12300/44848 file
# ✓ Đã xử lý 12400/44848 file
# ✓ Đã xử lý 12500/44848 file
# ✓ Đã xử lý 12600/44848 file
# ✓ Đã xử lý 12700/44848 file
# ✓ Đã xử lý 12800/44848 file
# ✓ Đã xử lý 12900/44848 file
# ✓ Đã xử lý 13000/44848 file
# ✓ Đã xử lý 13100/44848 file
# ✓ Đã xử lý 13200/44848 file
# ✓ Đã xử lý 13300/44848 file
# ✓ Đã xử lý 13400/44848 file
# ✓ Đã xử lý 13500/44848 file
# ✓ Đã xử lý 13600/44848 file
# ✓ Đã xử lý 13700/44848 file
# ✓ Đã xử lý 13800/44848 file
# ✓ Đã xử lý 13900/44848 file
# ✓ Đã xử lý 14000/44848 file
# ✓ Đã xử lý 14100/44848 file
# ✓ Đã xử lý 14200/44848 file
# ✓ Đã xử lý 14300/44848 file
# ✓ Đã xử lý 14400/44848 file
# ✓ Đã xử lý 14500/44848 file
# ✓ Đã xử lý 14600/44848 file
# ✓ Đã xử lý 14700/44848 file
# ✓ Đã xử lý 14800/44848 file
# ✓ Đã xử lý 14900/44848 file
# ✓ Đã xử lý 15000/44848 file
# ✓ Đã xử lý 15100/44848 file
# ✓ Đã xử lý 15200/44848 file
# ✓ Đã xử lý 15300/44848 file
# ✓ Đã xử lý 15400/44848 file
# ✓ Đã xử lý 15500/44848 file
# ✓ Đã xử lý 15600/44848 file
# ✓ Đã xử lý 15700/44848 file
# ✓ Đã xử lý 15800/44848 file
# ✓ Đã xử lý 15900/44848 file
# ✓ Đã xử lý 16000/44848 file
# ✓ Đã xử lý 16100/44848 file
# ✓ Đã xử lý 16200/44848 file
# ✓ Đã xử lý 16300/44848 file
# ✓ Đã xử lý 16400/44848 file
# ✓ Đã xử lý 16500/44848 file
# ✓ Đã xử lý 16600/44848 file
# ✓ Đã xử lý 16700/44848 file
# ✓ Đã xử lý 16800/44848 file
# ✓ Đã xử lý 16900/44848 file
# ✓ Đã xử lý 17000/44848 file
# ✓ Đã xử lý 17100/44848 file
# ✓ Đã xử lý 17200/44848 file
# ✓ Đã xử lý 17300/44848 file
# ✓ Đã xử lý 17400/44848 file
# ✓ Đã xử lý 17500/44848 file
# ✓ Đã xử lý 17600/44848 file
# ✓ Đã xử lý 17700/44848 file
# ✓ Đã xử lý 17800/44848 file
# ✓ Đã xử lý 17900/44848 file
# ✓ Đã xử lý 18000/44848 file
# ✓ Đã xử lý 18100/44848 file
# ✓ Đã xử lý 18200/44848 file
# ✓ Đã xử lý 18300/44848 file
# ✓ Đã xử lý 18400/44848 file
# ✓ Đã xử lý 18500/44848 file
# ✓ Đã xử lý 18600/44848 file
# ✓ Đã xử lý 18700/44848 file
# ✓ Đã xử lý 18800/44848 file
# ✓ Đã xử lý 18900/44848 file
# ✓ Đã xử lý 19000/44848 file
# ✓ Đã xử lý 19100/44848 file
# ✓ Đã xử lý 19200/44848 file
# ✓ Đã xử lý 19300/44848 file
# ✓ Đã xử lý 19400/44848 file
# ✓ Đã xử lý 19500/44848 file
# ✓ Đã xử lý 19600/44848 file
# ✓ Đã xử lý 19700/44848 file
# ✓ Đã xử lý 19800/44848 file
# ✓ Đã xử lý 19900/44848 file
# ✓ Đã xử lý 20000/44848 file
# ✓ Đã xử lý 20100/44848 file
# ✓ Đã xử lý 20200/44848 file
# ✓ Đã xử lý 20300/44848 file
# ✓ Đã xử lý 20400/44848 file
# ✓ Đã xử lý 20500/44848 file
# ✓ Đã xử lý 20600/44848 file
# ✓ Đã xử lý 20700/44848 file
# ✓ Đã xử lý 20800/44848 file
# ✓ Đã xử lý 20900/44848 file
# ✓ Đã xử lý 21000/44848 file
# ✓ Đã xử lý 21100/44848 file
# ✓ Đã xử lý 21200/44848 file
# ✓ Đã xử lý 21300/44848 file
# ✓ Đã xử lý 21400/44848 file
# ✓ Đã xử lý 21500/44848 file
# ✓ Đã xử lý 21600/44848 file
# ✓ Đã xử lý 21700/44848 file
# ✓ Đã xử lý 21800/44848 file
# ✓ Đã xử lý 21900/44848 file
# ✓ Đã xử lý 22000/44848 file
# ✓ Đã xử lý 22100/44848 file
# ✓ Đã xử lý 22200/44848 file
# ✓ Đã xử lý 22300/44848 file
# ✓ Đã xử lý 22400/44848 file
# ✓ Đã xử lý 22500/44848 file
# ✓ Đã xử lý 22600/44848 file
# ✓ Đã xử lý 22700/44848 file
# ✓ Đã xử lý 22800/44848 file
# ✓ Đã xử lý 22900/44848 file
# ✓ Đã xử lý 23000/44848 file
# ✓ Đã xử lý 23100/44848 file
# ✓ Đã xử lý 23200/44848 file
# ✓ Đã xử lý 23300/44848 file
# ✓ Đã xử lý 23400/44848 file
# ✓ Đã xử lý 23500/44848 file
# ✓ Đã xử lý 23600/44848 file
# ✓ Đã xử lý 23700/44848 file
# ✓ Đã xử lý 23800/44848 file
# ✓ Đã xử lý 23900/44848 file
# ✓ Đã xử lý 24000/44848 file
# ✓ Đã xử lý 24100/44848 file
# ✓ Đã xử lý 24200/44848 file
# ✓ Đã xử lý 24300/44848 file
# ✓ Đã xử lý 24400/44848 file
# ✓ Đã xử lý 24500/44848 file
# ✓ Đã xử lý 24600/44848 file
# ✓ Đã xử lý 24700/44848 file
# ✓ Đã xử lý 24800/44848 file
# ✓ Đã xử lý 24900/44848 file
# ✓ Đã xử lý 25000/44848 file
# ✓ Đã xử lý 25100/44848 file
# ✓ Đã xử lý 25200/44848 file
# ✓ Đã xử lý 25300/44848 file
# ✓ Đã xử lý 25400/44848 file
# ✓ Đã xử lý 25500/44848 file
# ✓ Đã xử lý 25600/44848 file
# ✓ Đã xử lý 25700/44848 file
# ✓ Đã xử lý 25800/44848 file
# ✓ Đã xử lý 25900/44848 file
# ✓ Đã xử lý 26000/44848 file
# ✓ Đã xử lý 26100/44848 file
# ✓ Đã xử lý 26200/44848 file
# ✓ Đã xử lý 26300/44848 file
# ✓ Đã xử lý 26400/44848 file
# ✓ Đã xử lý 26500/44848 file
# ✓ Đã xử lý 26600/44848 file
# ✓ Đã xử lý 26700/44848 file
# ✓ Đã xử lý 26800/44848 file
# ✓ Đã xử lý 26900/44848 file
# ✓ Đã xử lý 27000/44848 file
# ✓ Đã xử lý 27100/44848 file
# ✓ Đã xử lý 27200/44848 file
# ✓ Đã xử lý 27300/44848 file
# ✓ Đã xử lý 27400/44848 file
# ✓ Đã xử lý 27500/44848 file
# ✓ Đã xử lý 27600/44848 file
# ✓ Đã xử lý 27700/44848 file
# ✓ Đã xử lý 27800/44848 file
# ✓ Đã xử lý 27900/44848 file
# ✓ Đã xử lý 28000/44848 file
# ✓ Đã xử lý 28100/44848 file
# ✓ Đã xử lý 28200/44848 file
# ✓ Đã xử lý 28300/44848 file
# ✓ Đã xử lý 28400/44848 file
# ✓ Đã xử lý 28500/44848 file
# ✓ Đã xử lý 28600/44848 file
# ✓ Đã xử lý 28700/44848 file
# ✓ Đã xử lý 28800/44848 file
# ✓ Đã xử lý 28900/44848 file
# ✓ Đã xử lý 29000/44848 file
# ✓ Đã xử lý 29100/44848 file
# ✓ Đã xử lý 29200/44848 file
# ✓ Đã xử lý 29300/44848 file
# ✓ Đã xử lý 29400/44848 file
# ✓ Đã xử lý 29500/44848 file
# ✓ Đã xử lý 29600/44848 file
# ✓ Đã xử lý 29700/44848 file
# ✓ Đã xử lý 29800/44848 file
# ✓ Đã xử lý 29900/44848 file
# ✓ Đã xử lý 30000/44848 file
# ✓ Đã xử lý 30100/44848 file
# ✓ Đã xử lý 30200/44848 file
# ✓ Đã xử lý 30300/44848 file
# ✓ Đã xử lý 30400/44848 file
# ✓ Đã xử lý 30500/44848 file
# ✓ Đã xử lý 30600/44848 file
# ✓ Đã xử lý 30700/44848 file
# ✓ Đã xử lý 30800/44848 file
# ✓ Đã xử lý 30900/44848 file
# ✓ Đã xử lý 31000/44848 file
# ✓ Đã xử lý 31100/44848 file
# ✓ Đã xử lý 31200/44848 file
# ✓ Đã xử lý 31300/44848 file
# ✓ Đã xử lý 31400/44848 file
# ✓ Đã xử lý 31500/44848 file
# ✓ Đã xử lý 31600/44848 file
# ✓ Đã xử lý 31700/44848 file
# ✓ Đã xử lý 31800/44848 file
# ✓ Đã xử lý 31900/44848 file
# ✓ Đã xử lý 32000/44848 file
# ✓ Đã xử lý 32100/44848 file
# ✓ Đã xử lý 32200/44848 file
# ✓ Đã xử lý 32300/44848 file
# ✓ Đã xử lý 32400/44848 file
# ✓ Đã xử lý 32500/44848 file
# ✓ Đã xử lý 32600/44848 file
# ✓ Đã xử lý 32700/44848 file
# ✓ Đã xử lý 32800/44848 file
# ✓ Đã xử lý 32900/44848 file
# ✓ Đã xử lý 33000/44848 file
# ✓ Đã xử lý 33100/44848 file
# ✓ Đã xử lý 33200/44848 file
# ✓ Đã xử lý 33300/44848 file
# ✓ Đã xử lý 33400/44848 file
# ✓ Đã xử lý 33500/44848 file
# ✓ Đã xử lý 33600/44848 file
# ✓ Đã xử lý 33700/44848 file
# ✓ Đã xử lý 33800/44848 file
# ✓ Đã xử lý 33900/44848 file
# ✓ Đã xử lý 34000/44848 file
# ✓ Đã xử lý 34100/44848 file
# ✓ Đã xử lý 34200/44848 file
# ✓ Đã xử lý 34300/44848 file
# ✓ Đã xử lý 34400/44848 file
# ✓ Đã xử lý 34500/44848 file
# ✓ Đã xử lý 34600/44848 file
# ✓ Đã xử lý 34700/44848 file
# ✓ Đã xử lý 34800/44848 file
# ✓ Đã xử lý 34900/44848 file
# ✓ Đã xử lý 35000/44848 file
# ✓ Đã xử lý 35100/44848 file
# ✓ Đã xử lý 35200/44848 file
# ✓ Đã xử lý 35300/44848 file
# ✓ Đã xử lý 35400/44848 file
# ✓ Đã xử lý 35500/44848 file
# ✓ Đã xử lý 35600/44848 file
# ✓ Đã xử lý 35700/44848 file
# ✓ Đã xử lý 35800/44848 file
# ✓ Đã xử lý 35900/44848 file
# ✓ Đã xử lý 36000/44848 file
# ✓ Đã xử lý 36100/44848 file
# ✓ Đã xử lý 36200/44848 file
# ✓ Đã xử lý 36300/44848 file
# ✓ Đã xử lý 36400/44848 file
# ✓ Đã xử lý 36500/44848 file
# ✓ Đã xử lý 36600/44848 file
# ✓ Đã xử lý 36700/44848 file
# ✓ Đã xử lý 36800/44848 file
# ✓ Đã xử lý 36900/44848 file
# ✓ Đã xử lý 37000/44848 file
# ✓ Đã xử lý 37100/44848 file
# ✓ Đã xử lý 37200/44848 file
# ✓ Đã xử lý 37300/44848 file
# ✓ Đã xử lý 37400/44848 file
# ✓ Đã xử lý 37500/44848 file
# ✓ Đã xử lý 37600/44848 file
# ✓ Đã xử lý 37700/44848 file
# ✓ Đã xử lý 37800/44848 file
# ✓ Đã xử lý 37900/44848 file
# ✓ Đã xử lý 38000/44848 file
# ✓ Đã xử lý 38100/44848 file
# ✓ Đã xử lý 38200/44848 file
# ✓ Đã xử lý 38300/44848 file
# ✓ Đã xử lý 38400/44848 file
# ✓ Đã xử lý 38500/44848 file
# ✓ Đã xử lý 38600/44848 file
# ✓ Đã xử lý 38700/44848 file
# ✓ Đã xử lý 38800/44848 file
# ✓ Đã xử lý 38900/44848 file
# ✓ Đã xử lý 39000/44848 file
# ✓ Đã xử lý 39100/44848 file
# ✓ Đã xử lý 39200/44848 file
# ✓ Đã xử lý 39300/44848 file
# ✓ Đã xử lý 39400/44848 file
# ✓ Đã xử lý 39500/44848 file
# ✓ Đã xử lý 39600/44848 file
# ✓ Đã xử lý 39700/44848 file
# ✓ Đã xử lý 39800/44848 file
# ✓ Đã xử lý 39900/44848 file
# ✓ Đã xử lý 40000/44848 file
# ✓ Đã xử lý 40100/44848 file
# ✓ Đã xử lý 40200/44848 file
# ✓ Đã xử lý 40300/44848 file
# ✓ Đã xử lý 40400/44848 file
# ✓ Đã xử lý 40500/44848 file
# ✓ Đã xử lý 40600/44848 file
# ✓ Đã xử lý 40700/44848 file
# ✓ Đã xử lý 40800/44848 file
# ✓ Đã xử lý 40900/44848 file
# ✓ Đã xử lý 41000/44848 file
# ✓ Đã xử lý 41100/44848 file
# ✓ Đã xử lý 41200/44848 file
# ✓ Đã xử lý 41300/44848 file
# ✓ Đã xử lý 41400/44848 file
# ✓ Đã xử lý 41500/44848 file
# ✓ Đã xử lý 41600/44848 file
# ✓ Đã xử lý 41700/44848 file
# ✓ Đã xử lý 41800/44848 file
# ✓ Đã xử lý 41900/44848 file
# ✓ Đã xử lý 42000/44848 file
# ✓ Đã xử lý 42100/44848 file
# ✓ Đã xử lý 42200/44848 file
# ✓ Đã xử lý 42300/44848 file
# ✓ Đã xử lý 42400/44848 file
# ✓ Đã xử lý 42500/44848 file
# ✓ Đã xử lý 42600/44848 file
# ✓ Đã xử lý 42700/44848 file
# ✓ Đã xử lý 42800/44848 file
# ✓ Đã xử lý 42900/44848 file
# ✓ Đã xử lý 43000/44848 file
# ✓ Đã xử lý 43100/44848 file
# ✓ Đã xử lý 43200/44848 file
# ✓ Đã xử lý 43300/44848 file
# ✓ Đã xử lý 43400/44848 file
# ✓ Đã xử lý 43500/44848 file
# ✓ Đã xử lý 43600/44848 file
# ✓ Đã xử lý 43700/44848 file
# ✓ Đã xử lý 43800/44848 file
# ✓ Đã xử lý 43900/44848 file
# ✓ Đã xử lý 44000/44848 file
# ✓ Đã xử lý 44100/44848 file
# ✓ Đã xử lý 44200/44848 file
# ✓ Đã xử lý 44300/44848 file
# ✓ Đã xử lý 44400/44848 file
# ✓ Đã xử lý 44500/44848 file
# ✓ Đã xử lý 44600/44848 file
# ✓ Đã xử lý 44700/44848 file
# ✓ Đã xử lý 44800/44848 file
# ✅ Hoàn tất! Lưu 44848 bản ghi hợp lệ vào 'E:\NCKH - 2026\ECG Project\data\processed\ecg_lead6_npy'.
# ✅ Hoàn tất xử lý tín hiệu cho 44848 bản ghi hợp lệ

# %% [markdown]
# # **CHIA THƯ MỤC TRAIN/VAL/TEST**

# %%
# === Bước 3: Chia dữ liệu train/val/test ===
run_split_dataset()

# Sau bước này sẽ có thư mục:
# data/splits/
# ├── train_files.npy
# ├── val_files.npy
# ├── test_files.npy
# ├── y_train.npy
# ├── y_val.npy
# └── y_test.npy
# Out:
# ===== Bước 3: Chia dữ liệu train/val/test =====
# 🔹 Tổng số file tín hiệu ECG: 44848
# ✅ Train: 31393, Val: 4485, Test: 8970
# y_train shape: (31393, 10)
# y_val shape: (4485, 10)
# y_test shape: (8970, 10)
# 📁 Đã lưu toàn bộ file chia tập vào: E:\NCKH - 2026\ECG Project\data\processed\ecg_lead6_npy\..\splits_v6
# ✅ Hoàn tất chia dữ liệu!
