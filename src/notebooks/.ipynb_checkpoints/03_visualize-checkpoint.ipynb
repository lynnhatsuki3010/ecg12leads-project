# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 📘 03_visualizing.ipynb
# Nhiệm vụ: Trực quan dữ liệu ECG, attention map và Grad-CAM

import os, sys
sys.path.append("../")

import torch
import numpy as np
import matplotlib.pyplot as plt

from visualize.plot_signals import load_ecg_mat, plot_ecg_signals, plot_spectrogram, plot_compare
from visualize.plot_statistics import analyze_top_diseases
from visualize.attention_map import get_attention_weights, plot_attention_dots
from visualize.generate_attention_maps import generate_attention_visualizations
from visualize.gradcam import visualize_gradcam_multilabel

from training.model_resnet50 import ResNet1D50Attention
from training.model import ResNet1DAttention
from training.resnet1d import ResNet1D
from training.dataset_loader import ECGDataset
from training.model_resnet18_lstm import ResNet18_LSTM_Attn

# %% [markdown]
# ### **ATTENTION NEW UPDATE 17/1/25**

# %%
import torch
import numpy as np
from training.model_resnet18_lstm import ResNet18_LSTM_Attn
from visualize.attention_map import get_attention_weights, plot_attention_dots
from misc.swa_fix import load_swa_model

# Load model
device = "cuda" if torch.cuda.is_available() else "cpu"
model = ResNet18_LSTM_Attn(num_classes=5, input_channels=12).to(device)
model_path = r"E:\NCKH - 2026\ECG Project\models\resnet18_lstm_mixup_swa_160125.pth"

model = load_swa_model(model_path, model, device) #swa
model.eval()

# Load sample
signal = torch.tensor(
    np.load(r"E:\NCKH - 2026\ECG Project\data\processed\ecg_leads12_160125\JS00004.npy"), 
    dtype=torch.float32
)

# Visualize
attn_weights = get_attention_weights(model, signal)
fig = plot_attention_dots(signal, attn_weights, sample_idx=1, label_true="SB")
#fig.savefig("attention_map.png", dpi=300)

# %%
# === Đường dẫn chính ===
base_dir = r"E:\NCKH - 2026\ECG Project"
splits_dir = os.path.join(base_dir, "data", "processed", "splits_leads12_160125")
npy_dir = os.path.join(base_dir, "data", "processed", "ecg_leads12_160125")
output_dir = os.path.join(base_dir, "data", "processed", "attention_visualize_170125")

# === Bản đồ nhãn (10 lớp) ===
label_map = {
        "426177001": "SB",    # SB
        "426783006": "SR",    # SR
        "164890007": "AF",    # AF
        "426761007": "SVT",
        "427084000": "ST",    # ST 
}

# === Load mô hình đã huấn luyện ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_path = os.path.join(base_dir, "models", "resnet18_lstm_mixup_swa_160125.pth")

model = ResNet18_LSTM_Attn(
    num_classes=len(label_map),
    input_channels=12 
).to(device)
    
model = load_swa_model(model_path, model, device)
model.eval()

# === Sinh ảnh Attention ===
generate_attention_visualizations(
    model=model,
    train_files_path=os.path.join(splits_dir, "test_files.npy"),
    y_train_path=os.path.join(splits_dir, "y_test.npy"),
    ecg_npy_dir=npy_dir,
    output_root=output_dir,
    label_map=label_map,
    device=device
)
# Out:
# Tổng số mẫu: 4421
# Generating Attention:   0%|▎                                                       | 20/4421 [02:32<9:12:54,  7.54s/it]E:\NCKH - 2026\ECG Project\src\notebooks\..\visualize\attention_map.py:127: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(y_min - margin, y_max + margin)
# Generating Attention:   8%|████▎                                                | 361/4421 [1:19:09<7:51:52,  6.97s/it]
# [Warning] Lỗi khi xử lý E:\NCKH - 2026\ECG Project\data\processed\ecg_leads12_160125\JS32123.npy: bad allocation
# Generating Attention:   8%|████▎                                               | 362/4421 [1:19:28<12:10:29, 10.80s/it]
# [Warning] Lỗi khi xử lý E:\NCKH - 2026\ECG Project\data\processed\ecg_leads12_160125\JS32182.npy: bad allocation
# Generating Attention:   8%|████▎                                               | 363/4421 [1:19:40<14:50:36, 13.17s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 29
#      26 model.eval()
#      28 # === Sinh ảnh Attention ===
# ---> 29 generate_attention_visualizations(
#      30     model=model,
#      31     train_files_path=os.path.join(splits_dir, "test_files.npy"),
#      32     y_train_path=os.path.join(splits_dir, "y_test.npy"),
#      33     ecg_npy_dir=npy_dir,
#      34     output_root=output_dir,
#      35     label_map=label_map,
#      36     device=device
#      37 )
#
# File E:\NCKH - 2026\ECG Project\src\notebooks\..\visualize\generate_attention_maps.py:61, in generate_attention_visualizations(model, train_files_path, y_train_path, ecg_npy_dir, output_root, label_map, device)
#      58 attn_weights = get_attention_weights(model, signal)
#      60 # === Vẽ attention ===
# ---> 61 fig = plot_attention_dots(
#      62     signal=signal,
#      63     attn_weights=attn_weights,
#      64     fs=500,
#      65     paper_speed=25
#      66 )
#      68 # === Lưu ảnh ===
#      69 output_label_dir = os.path.join(output_root, label_name)
#
# File E:\NCKH - 2026\ECG Project\src\notebooks\..\visualize\attention_map.py:137, in plot_attention_dots(signal, attn_weights, sample_idx, label_true, fs, paper_speed, show_rr, lead_names)
#     135 # Minor ticks (0.04s)
#     136 ax.set_xticks(np.arange(0, time[-1], small_box_s), minor=True)
# --> 137 ax.grid(which='minor', axis='x', color='pink', linewidth=0.3, alpha=0.5)
#     139 # 2. Lưới Ngang (Biên độ)
#     140 if is_zscore:
#     141     # Nếu là Z-score: Vẽ lưới nét đứt mờ, không theo chuẩn 0.1mV/0.5mV
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:3357, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3355 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3356 if axis in ['x', 'both']:
# -> 3357     self.xaxis.grid(visible, which=which, **kwargs)
#    3358 if axis in ['y', 'both']:
#    3359     self.yaxis.grid(visible, which=which, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1731, in Axis.grid(self, visible, which, **kwargs)
#    1728 if which in ['minor', 'both']:
#    1729     gridkw['gridOn'] = (not self._minor_tick_kw['gridOn']
#    1730                         if visible is None else visible)
# -> 1731     self.set_tick_params(which='minor', **gridkw)
#    1732 if which in ['major', 'both']:
#    1733     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1734                         if visible is None else visible)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:980, in Axis.set_tick_params(self, which, reset, **kwargs)
#     978     self._minor_tick_kw.update(kwtrans)
#     979     for tick in self.minorTicks:
# --> 980         tick._apply_params(**kwtrans)
#     981 # labelOn and labelcolor also apply to the offset text.
#     982 if 'label1On' in kwtrans or 'label2On' in kwtrans:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:310, in Tick._apply_params(self, **kwargs)
#     308     if name in kwargs:
#     309         target.set_visible(kwargs.pop(name))
# --> 310 if any(k in kwargs for k in ['size', 'width', 'pad', 'tickdir']):
#     311     self._size = kwargs.pop('size', self._size)
#     312     # Width could be handled outside this block, but it is
#     313     # convenient to leave it here.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:310, in <genexpr>(.0)
#     308     if name in kwargs:
#     309         target.set_visible(kwargs.pop(name))
# --> 310 if any(k in kwargs for k in ['size', 'width', 'pad', 'tickdir']):
#     311     self._size = kwargs.pop('size', self._size)
#     312     # Width could be handled outside this block, but it is
#     313     # convenient to leave it here.
#
# KeyboardInterrupt:

# %% [markdown]
# # **EDA ECG**

# %%
# === Hiển thị tín hiệu ECG ===

mat_path = r"E:\NCKH - 2026\ECG Project\data\raw\WFDBRecords\01\010\JS00001.mat"
signals = load_ecg_mat(mat_path)

# Plot 12 đạo trình
plot_ecg_signals(signals, title="Raw ECG 12 leads")

# Plot spectrogram của đạo trình V2
plot_spectrogram(signals, fs=500, lead_index=6)

# %%
# === Phân tích tần suất bệnh top N ===
metadata_path = r"E:\NCKH - 2026\ECG Project\data\processed\patient_metadata_superclean.xlsx"
snomed_path = r"E:\NCKH - 2026\ECG Project\data\raw\ConditionNames_SNOMED-CT.csv"

analyze_top_diseases(metadata_path, snomed_path, top_n=25)
# Out:
#          Code  Count Disease_Name  Percentage
# 0   426177001  16542           SB   23.429267
# 1   164890007   8010           AF   11.344966
# 2   426783006   7962           SR   11.276981
# 3   427084000   7244           ST   10.260042
# 4   164934002   7006          TWC    9.922951
# 5    59931005   2866          TWO    4.059260
# 6   427393009   2546           SA    3.606028
# 7   164889003   1780         AFIB    2.521104
# 8   429622005   1665         STDD    2.358223
# 9    39732003   1537          ALS    2.176930
# 10  284470004   1299          APB    1.839839
# 11  428750005   1158         STTC    1.640134
# 12  270492004   1136         1AVB    1.608974
# 13  164917005   1053          AQW    1.491417
# 14  251146004   1037      LVQRSAL    1.468755
# 15   47665007    842          ARS    1.192567
# 16  164930006    796          STE    1.127415
# 17  698252002    764          IVB    1.082092
# 18  426761007    687          SVT    0.973033
# 19   59118001    649         RBBB    0.919211
# 20  164873001    638          LVH    0.903632
# 21  111975006    387         QTIE    0.548128
# 22  428417006    365          ERV    0.516968
# 23  713422000    296           AT    0.419240
# 24   17338001    294          VPB    0.416407

# %% [markdown]
# # **ATTENTION**

# %%
# === Attention Map (mô hình ResNet1D + Attention) ===

# Load mô hình
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_path = r"E:\NCKH - 2026\ECG Project\models\resnet1D96_model.pth"

model = ResNet1D(
    in_channels=6,
    base_filters=64,
    kernel_size=7,
    stride=2,
    groups=1,
    n_block=16,
    n_classes=10,        
    downsample_gap=2,
    increasefilter_gap=4,
    use_bn=True,
    use_do=True
).to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

# Load 1 mẫu tín hiệu test
sample_file = r"E:\NCKH - 2026\ECG Project\data\processed\ecg_lead6_npy\record_1.npy"
signal = torch.tensor(np.load(sample_file), dtype=torch.float32)

# Lấy trọng số attention
attn_weights = get_attention_weights(model, signal)

# Vẽ bản đồ chú ý
plot_attention_dots(signal, attn_weights, sample_idx=1, label_true="Nhịp chậm xoang")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10340\2052780870.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))

# %%
# === Đường dẫn chính ===
base_dir = r"E:\NCKH - 2026\ECG Project"
splits_dir = os.path.join(base_dir, "data", "processed", "splits_C7v12")
npy_dir = os.path.join(base_dir, "data", "processed", "ecg_leads12_7c")
output_dir = os.path.join(base_dir, "data", "processed", "attention_visualize_v12_7c")

# === Bản đồ nhãn (10 lớp) ===
label_map = {
        "426177001": "Nhịp chậm xoang - SB",           # SB
        "426783006": "Nhịp xoang bình thường - SR",    # SR
        "164890007": "Cuồng nhĩ - AF",                 # AF
        "427084000": "Nhịp xoang nhanh - ST",          # ST
        "164889003": "Rung nhĩ - AFIB",                  # AFIB
        "426761007": "Nhịp nhanh trên thất - SVT",
        "713422000": "Nhịp nhanh nhĩ - AT"
    
}


# === Load mô hình đã huấn luyện ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_path = os.path.join(base_dir, "models", "resnet501d_attention_v7_12L.pth")

model = ResNet1D50Attention(
    num_classes=len(label_map)   
).to(device)
state = torch.load(model_path, map_location=device)
model.load_state_dict(state)
model.eval()

# === Sinh ảnh Attention ===
generate_attention_visualizations(
    model=model,
    train_files_path=os.path.join(splits_dir, "train_files.npy"),
    y_train_path=os.path.join(splits_dir, "y_train.npy"),
    ecg_npy_dir=npy_dir,
    output_root=output_dir,
    label_map=label_map,
    device=device
)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_26656\2916874922.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(model_path, map_location=device)
# Tổng số mẫu: 30942
# Generating Attention:   0%|                                                       | 3/30942 [00:26<76:24:52,  8.89s/it]E:\NCKH - 2026\ECG Project\src\notebooks\..\visualize\attention_map.py:70: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(y_min, y_max)
# Generating Attention:   1%|▍                                                    | 226/30942 [51:23<81:01:06,  9.50s/it]

# %% [raw]
# # === Đường dẫn chính ===
# base_dir = r"E:\NCKH - 2026\ECG Project"
# splits_dir = os.path.join(base_dir, "data", "processed", "splits_v6")
# npy_dir = os.path.join(base_dir, "data", "processed", "ecg_lead6_npy")
# output_dir = os.path.join(base_dir, "data", "processed", "attention_visualize_v6")
#
# # === Bản đồ nhãn (10 lớp) ===
# label_map = {
#         "426177001": "Nhịp chậm xoang",           # SB
#         "426783006": "Nhịp xoang bình thường",    # SR
#         "164890007": "Cuồng nhĩ",                 # AF
#         "427084000": "Nhịp xoang nhanh",          # ST
#         "164934002": "Sóng T thay đổi hình dạng", # TWC
#         "59931005":  "Sóng T đảo ngược",          # TWO
#         "164889003": "Rung nhĩ",                  # AFIB
#         "429622005": "Đoạn ST chênh xuống",       # STDD
#         "39732003":  "Trục điện tim lệch trái",   # ALS
#         "164917005": "Sóng Q bất thường"          # AQW
# }
#
#
# # === Load mô hình đã huấn luyện ===
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model_path = os.path.join(base_dir, "models", "resnet1D96_model.pth")
#
# model = ResNet1D(
#     in_channels=6,
#     base_filters=64,
#     kernel_size=7,
#     stride=2,
#     groups=1,
#     n_block=16,
#     n_classes=len(label_map),
#     downsample_gap=2,
#     increasefilter_gap=4,
#     use_bn=True,
#     use_do=True
# ).to(device)
# state = torch.load(model_path, map_location=device)
# model.load_state_dict(state)
# model.eval()
#
# # === Sinh ảnh Attention ===
# generate_attention_visualizations(
#     model=model,
#     train_files_path=os.path.join(splits_dir, "train_files.npy"),
#     y_train_path=os.path.join(splits_dir, "y_train.npy"),
#     ecg_npy_dir=npy_dir,
#     output_root=output_dir,
#     label_map=label_map,
#     device=device
# )

# %%
import glob, os

files = glob.glob(r"E:\NCKH - 2026\ECG Project\data\processed\attention_visualize\**\*.png", recursive=True)
print("Tổng số ảnh tìm thấy:", len(files))
if files:
    print("Ví dụ:", files[:5])
# Out:
# Tổng số ảnh tìm thấy: 0

# %% [markdown]
# # **GRAD-CAM**

# %%
# === Grad-CAM Visualization ===

# Tải dataset test
split_dir = r"E:\NCKH - 2026\ECG Project\data\processed\splits"
X_test = np.load(os.path.join(split_dir, "test_files.npy"), allow_pickle=True)
y_test = np.load(os.path.join(split_dir, "y_test.npy"))

test_dataset = ECGDataset(X_test, y_test)

# Hiển thị Grad-CAM cho một mẫu bất kỳ
visualize_gradcam_multilabel(model, test_dataset, sample_idx=5, target_layer="layer3.conv2")
# Out:
#  Mẫu 5 | Dự đoán mạnh nhất: lớp 0 (p=0.966)
#    Nhãn thật (multi-hot): [1. 0. 0. 0. 0. 0. 0. 0.]
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1827: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)

# %% [raw]
# # === So sánh tín hiệu trước/sau lọc nhiễu ===
#
# raw_sig = np.load(r"E:\NCKH - 2026\ECG Project\data\raw\WFDBRecords\01\010\JS00001.mat")
# denoised_sig = np.load(r"E:\NCKH - 2026\ECG Project\data\processed\ecg_npy\record_1.npy")
#
# plot_compare(raw_sig, denoised_sig, lead_idx=6)
